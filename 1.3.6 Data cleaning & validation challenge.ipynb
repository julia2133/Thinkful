# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv',encoding='iso8859_15')

# %%
df.head(5)
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
(df.shape[0]-df.dropna().shape[0])/df.shape[0]
# Out:
# 0.09355900329102021

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['PMID/PMCID', 'Publisher', 'Journal title', 'Article title',
#        'COST (£) charged to Wellcome (inc VAT when charged)'],
#       dtype='object')

# %%
df['COST (£) charged to Wellcome (inc VAT when charged)'] = df['COST (£) charged to Wellcome (inc VAT when charged)'].str.replace('[£$]*', "")
df['COST (£) charged to Wellcome (inc VAT when charged)'] = df['COST (£) charged to Wellcome (inc VAT when charged)'].str.replace('[$£]?[.][0-9]{0,2}[$£]*', "")

# %%
df.rename(inplace=True, columns={'COST (£) charged to Wellcome (inc VAT when charged)':'cost'})
df.cost = pd.to_numeric(df.cost, errors='coerce').fillna(0).astype(np.int64)

# %%
journals = df['Journal title'].unique()

# %%
df.loc[df['Journal title'] == journals[0], 'cost']
# Out:
# 1    2381
# Name: cost, dtype: int64

# %%
for journal in journals:
    art_cost = df.loc[df['Journal title'] == journal, 'cost']
    print(journal)
    print({art_cost.mean()})
    print({art_cost.median()})
    print({art_cost.std()})
    print('\n')
# Out:
# Biomacromolecules
# {2381.0}
# {2381.0}
# {nan}
#
#
# J Med Chem
# {655.5}
# {655.5}
# {19.091883092036785}
#
#
# J Org Chem
# {685.0}
# {685.0}
# {nan}
#
#
# Journal of Medicinal Chemistry
# {1221.8333333333333}
# {1146.5}
# {644.2777092734675}
#
#
# Journal of Proteome Research
# {1844.0}
# {1844.0}
# {739.6336931211287}
#
#
# Mol Pharm
# {649.0}
# {649.0}
# {nan}
#
#
# ACS Chemical Biology
# {1535.25}
# {1294.0}
# {500.6618120048702}
#
#
# Journal of Chemical Information and Modeling
# {1329.0}
# {1329.0}
# {nan}
#
#
# Biochemistry
# {665.0}
# {665.0}
# {nan}
#
#
# Gastroenterology
# {1233.0}
# {1233.0}
# {1407.1424945612296}
#
#
# Journal of Biological Chemistry
# {22679.68085106383}
# {1287.0}
# {145656.3540746128}
#
#
# Journal of Immunology
# {2358.3333333333335}
# {2035.0}
# {651.2697853680403}
#
#
# ACS Chemical Neuroscience
# {1186.0}
# {1186.0}
# {nan}
#
#
# ACS NANO
# {642.0}
# {642.0}
# {nan}
#
#
# American Chemical Society
# {1533.0}
# {1533.0}
# {nan}
#
#
# ...
