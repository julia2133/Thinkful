# %% [markdown]
# ### Drill: Present the same data multiple ways
# The best way to learn plotting is to make a lot of plots. To complete the following you may need to explore the seaborn documentation.
#
# Drills
# Find a dataset you'd like to explore. This can be something you're familiar with or something new. Create a Jupyter notebook and then:
#
# Choose one variable and plot that variable four different ways.
# Choose two continuous variables, and plot them three different ways.
# Choose one continuous variable and one categorical variable, and plot them six different ways.
# Give the pros and cons of each plot you create. You can use variables from multiple datasets if you like.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import math
import seaborn as sns

# %%
df_all = pd.read_csv(r'C:\Users\julia\Dropbox\Data Science 2\Petfinder\train.csv')
# Remove string columns
df_all=df_all.drop(['Name','RescuerID', 'Description', 'PetID'], axis=1)

# %%
# Separate the dataset into cats and dogs.
df_dog=df_all[df_all.Type==1]
df_cat=df_all[df_all.Type==2]

# Obtain counts for each adoption speed
dog_counts = df_dog['AdoptionSpeed'].value_counts(sort=False).sort_index()
cat_counts = df_cat['AdoptionSpeed'].value_counts(sort=False).sort_index()
all_counts = df_all['AdoptionSpeed'].value_counts(sort=False).sort_index()

# %%
plt.bar(range(len(dog_counts)),dog_counts)
# Out:
# <BarContainer object of 5 artists>

# %%
sns.distplot(df_dog['AdoptionSpeed'])
plt.ylabel('Fraction of Animals',fontsize=15)
# Out:
# Text(0, 0.5, 'Fraction of Animals')

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x="AdoptionSpeed", y="Age",  data=df_all)
plt.ylabel('Number of Animals',fontsize=10)
# Out:
# Text(0, 0.5, 'Number of Animals')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="AdoptionSpeed", y="Age",  data=df_all)
plt.ylabel('Number of Animals',fontsize=10)
# Out:
# Text(0, 0.5, 'Number of Animals')

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x="AdoptionSpeed", y="Age",  data=df_all)
plt.ylabel('Number of Animals',fontsize=10)
# Out:
# Text(0, 0.5, 'Number of Animals')

# %%
plt.scatter(range(len(df_all)),df_all['Age'])
